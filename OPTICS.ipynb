# %%
import pandas as pd

# %%
dataset=pd.read_csv("Mall_Customers.csv")

# %%
x=dataset.iloc[:,[3,4]]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
from sklearn.cluster import OPTICS
opt=OPTICS(min_samples=5, xi=0.1, min_cluster_size=0.1)
clusout=opt.fit_predict(x)

# %%
unsupervised=dataset
unsupervised['clustergroup']=clusout
unsupervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      clustergroup
# 0              -1
# 1              -1
# 2              -1
# ...

# %%
import seaborn as sb
sb.lmplot(unsupervised,x=unsupervised.columns[3],y=unsupervised.columns[4],hue=unsupervised.columns[5],fit_reg=False,legend=True,legend_out=True)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\regression.py:598: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)

# %%
from sklearn.metrics import silhouette_score
ss=silhouette_score(x,clusout)
ss
# Out:
# 0.17014927509999947
